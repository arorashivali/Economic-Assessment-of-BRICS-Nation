# %%
import pandas as pd
import numpy as np

# %%
Brics=pd.read_csv('China.csv')

# %%
Brics
# Out:
#       Year  GDP Growth  Exports of goods and services (% of GDP)  \
# 0   1970.0        19.3                                       2.5
# 1   1971.0         7.1                                       2.8
# 2   1972.0         3.8                                       3.2
# 3   1973.0         7.8                                       4.2
# 4   1974.0         2.3                                       4.9
# 5   1975.0         8.7                                       4.7
# 6   1976.0        -1.6                                       4.5
# 7   1977.0         7.6                                       4.3
# 8   1978.0        11.3                                       4.6
# 9   1979.0         7.6                                       5.2
# 10  1980.0         7.8                                       5.9
# 11  1981.0         5.1                                       7.4
# 12  1982.0         9.0                                      11.0
# ...

# %%
Brics.head()
# Out:
#      Year  GDP Growth  Exports of goods and services (% of GDP)  \
# 0  1970.0        19.3                                       2.5
# 1  1971.0         7.1                                       2.8
# 2  1972.0         3.8                                       3.2
# 3  1973.0         7.8                                       4.2
# 4  1974.0         2.3                                       4.9
#
#    GDP per capita (current US$)  Gross domestic savings (% of GDP)  \
# 0                         113.2                               36.1
# 1                         118.7                               36.8
# 2                         131.9                               35.7
# 3                         157.1                               36.5
# 4                         160.1                               36.1
#
#    Trade in services (% of GDP)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# ...

# %%
Brics.describe()
# Out:
#              Year  GDP Growth  Exports of goods and services (% of GDP)  \
# count    50.00000    50.00000                                 50.000000
# mean   1994.50000     9.02200                                 16.416000
# std      14.57738     3.51407                                  9.369781
# min    1970.00000    -1.60000                                  2.500000
# 25%    1982.25000     7.45000                                  8.400000
# 50%    1994.50000     8.95000                                 17.950000
# 75%    2006.75000    10.95000                                 22.300000
# max    2019.00000    19.30000                                 36.000000
#
#        GDP per capita (current US$)  Gross domestic savings (% of GDP)  \
# count                      50.00000                          50.000000
# mean                     2112.39400                          40.518000
# std                      2990.51313                           5.320722
# ...

# %%
result = Brics.dtypes

# %%
result
# Out:
# Year                                                              float64
# GDP Growth                                                        float64
# Exports of goods and services (% of GDP)                          float64
# GDP per capita (current US$)                                      float64
# Gross domestic savings (% of GDP)                                 float64
# Trade in services (% of GDP)                                      float64
# Households and NPISHs final consumption expenditure (% of GDP)    float64
# Current account balance (% of GDP)                                float64
# Final consumption expenditure (% of GDP)                          float64
# Foreign direct investment, net inflows (% of GDP)                 float64
# Education expenditure                                             float64
# Population                                                          int64
# dtype: object

# %%
Brics.shape
# Out:
# (51, 12)

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="mean")
imputer.fit(Brics)
# Out:
# SimpleImputer()

# %%
imputer.statistics_
# Out:
# array([1.99450000e+03, 9.02200000e+00, 1.64160000e+01, 2.11239400e+03,
#        4.05180000e+01, 5.59210526e+00, 4.52340000e+01, 2.16052632e+00,
#        5.94820000e+01, 2.58292683e+00, 1.73800000e+00, 1.16860930e+09])

# %%
imputer.fit(Brics)
X=imputer.transform(Brics)
Brics_tr=pd.DataFrame(X, columns=Brics.columns)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set=train_test_split(Brics_tr, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\n Rows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 40
#  Rows in test set: 11

# %%
Brics_tr=train_set.copy()
Brics_te=test_set.copy()

# %%
Brics_tr
# Out:
#       Year  GDP Growth  Exports of goods and services (% of GDP)  \
# 8   1978.0      11.300                                     4.600
# 49  2019.0       5.900                                    18.400
# 6   1976.0      -1.600                                     4.500
# 47  2017.0       6.900                                    19.700
# 4   1974.0       2.300                                     4.900
# 36  2006.0      12.700                                    36.000
# 33  2003.0      10.000                                    27.000
# 19  1989.0       4.200                                    11.800
# 48  2018.0       6.700                                    19.100
# 15  1985.0      13.400                                     8.300
# 9   1979.0       7.600                                     5.200
# 16  1986.0       8.900                                     8.700
# 26  1996.0       9.900                                    17.900
# ...

# %%
result = Brics_tr.dtypes

# %%
result
# Out:
# Year                                                              float64
# GDP Growth                                                        float64
# Exports of goods and services (% of GDP)                          float64
# GDP per capita (current US$)                                      float64
# Gross domestic savings (% of GDP)                                 float64
# Trade in services (% of GDP)                                      float64
# Households and NPISHs final consumption expenditure (% of GDP)    float64
# Current account balance (% of GDP)                                float64
# Final consumption expenditure (% of GDP)                          float64
# Foreign direct investment, net inflows (% of GDP)                 float64
# Education expenditure                                             float64
# Population                                                        float64
# dtype: object

# %%
Brics_tr
# Out:
#       Year  GDP Growth  Exports of goods and services (% of GDP)  \
# 8   1978.0      11.300                                     4.600
# 49  2019.0       5.900                                    18.400
# 6   1976.0      -1.600                                     4.500
# 47  2017.0       6.900                                    19.700
# 4   1974.0       2.300                                     4.900
# 36  2006.0      12.700                                    36.000
# 33  2003.0      10.000                                    27.000
# 19  1989.0       4.200                                    11.800
# 48  2018.0       6.700                                    19.100
# 15  1985.0      13.400                                     8.300
# 9   1979.0       7.600                                     5.200
# 16  1986.0       8.900                                     8.700
# 26  1996.0       9.900                                    17.900
# ...

# %%
Corelation_matrix=Brics.corr()

# %%
Corelation_matrix
# Out:
#                                                         Year  GDP Growth  \
# Year                                                1.000000    0.026712
# GDP Growth                                          0.026712    1.000000
# Exports of goods and services (% of GDP)            0.849530    0.228925
# GDP per capita (current US$)                        0.817584   -0.176648
# Gross domestic savings (% of GDP)                   0.823316    0.151686
# Trade in services (% of GDP)                        0.537179   -0.104726
# Households and NPISHs final consumption expendi... -0.911868   -0.126386
# Current account balance (% of GDP)                  0.368096    0.074393
# Final consumption expenditure (% of GDP)           -0.823316   -0.151686
# Foreign direct investment, net inflows (% of GDP)   0.404744    0.358967
# Education expenditure                               0.552773   -0.044574
# Population                                          0.989310    0.058125
#
# ...

# %%
Corelation_matrix["GDP Growth"].sort_values(ascending=False)
# Out:
# GDP Growth                                                        1.000000
# Foreign direct investment, net inflows (% of GDP)                 0.358967
# Exports of goods and services (% of GDP)                          0.228925
# Gross domestic savings (% of GDP)                                 0.151686
# Current account balance (% of GDP)                                0.074393
# Population                                                        0.058125
# Year                                                              0.026712
# Education expenditure                                            -0.044574
# Trade in services (% of GDP)                                     -0.104726
# Households and NPISHs final consumption expenditure (% of GDP)   -0.126386
# Final consumption expenditure (% of GDP)                         -0.151686
# GDP per capita (current US$)                                     -0.176648
# Name: GDP Growth, dtype: float64

# %%
#columns = ["GDP per capita (current US$)", "Year", "Population", "Education expenditure", "Trade in services (% of GDP)", "Current account balance (% of GDP)i", "Gross domestic savings (% of GDP)", "Households and NPISHs final consumption expenditure (% of GDP)"]
#Brics = Brics.reindex(columns=columns)

# %%
from pandas.plotting import scatter_matrix
attributes=["GDP per capita (current US$)", "Year", "Population", "Trade in services (% of GDP)"]
scatter_matrix(Brics[attributes], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='GDP per capita (current US$)'>,
#         <AxesSubplot:xlabel='Year', ylabel='GDP per capita (current US$)'>,
#         <AxesSubplot:xlabel='Population', ylabel='GDP per capita (current US$)'>,
#         <AxesSubplot:xlabel='Trade in services (% of GDP)', ylabel='GDP per capita (current US$)'>],
#        [<AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='Year'>,
#         <AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Population', ylabel='Year'>,
#         <AxesSubplot:xlabel='Trade in services (% of GDP)', ylabel='Year'>],
#        [<AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='Population'>,
#         <AxesSubplot:xlabel='Year', ylabel='Population'>,
#         <AxesSubplot:xlabel='Population', ylabel='Population'>,
#         <AxesSubplot:xlabel='Trade in services (% of GDP)', ylabel='Population'>],
# ...

# %%
Brics.plot(kind="scatter", x="GDP per capita (current US$)", y="Population" )
# Out:
# <AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='Population'>

# %%
import seaborn as sns
 
# checking correlation using heatmap
#Loading dataset
 
#plotting the heatmap for correlation
ax = sns.heatmap(Brics.corr(), annot=True)

# %%
Brics_tr=train_set.drop("GDP Growth", axis=1)
Brics_labels_tr= train_set["GDP Growth"].copy()

# %%
Brics_tr
# Out:
#       Year  Exports of goods and services (% of GDP)  \
# 8   1978.0                                     4.600
# 49  2019.0                                    18.400
# 6   1976.0                                     4.500
# 47  2017.0                                    19.700
# 4   1974.0                                     4.900
# 36  2006.0                                    36.000
# 33  2003.0                                    27.000
# 19  1989.0                                    11.800
# 48  2018.0                                    19.100
# 15  1985.0                                     8.300
# 9   1979.0                                     5.200
# 16  1986.0                                     8.700
# 26  1996.0                                    17.900
# 44  2014.0                                    23.500
# 25  1995.0                                    18.000
# 11  1981.0                                     7.400
# 0   1970.0                                     2.500
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([('imputer', SimpleImputer(strategy="mean")), ('std_scaler', StandardScaler())])

# %%
Brics_num_tr=my_pipeline.fit_transform(Brics_tr)

# %%
Brics_tr
# Out:
#       Year  Exports of goods and services (% of GDP)  \
# 8   1978.0                                     4.600
# 49  2019.0                                    18.400
# 6   1976.0                                     4.500
# 47  2017.0                                    19.700
# 4   1974.0                                     4.900
# 36  2006.0                                    36.000
# 33  2003.0                                    27.000
# 19  1989.0                                    11.800
# 48  2018.0                                    19.100
# 15  1985.0                                     8.300
# 9   1979.0                                     5.200
# 16  1986.0                                     8.700
# 26  1996.0                                    17.900
# 44  2014.0                                    23.500
# 25  1995.0                                    18.000
# 11  1981.0                                     7.400
# 0   1970.0                                     2.500
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
#from lightgbm import LGBMRegressor
#from xgboost.sklearn import XGBRegressor
#model=LinearRegression()
#model=DecisionTreeRegressor()
#model=GradientBoostingRegressor()
#model=ElasticNet()
#model=SVR()
#model=SGDRegressor()
model=RandomForestRegressor()
#model=XGBRegressor
model.fit(Brics_num_tr, Brics_labels_tr)
# Out:
# RandomForestRegressor()

# %%
some_data=Brics_tr[:5]

# %%
some_data
# Out:
#       Year  Exports of goods and services (% of GDP)  \
# 8   1978.0                                       4.6
# 49  2019.0                                      18.4
# 6   1976.0                                       4.5
# 47  2017.0                                      19.7
# 4   1974.0                                       4.9
#
#     GDP per capita (current US$)  Gross domestic savings (% of GDP)  \
# 8                          156.4                               39.3
# 49                       10143.8                               44.0
# 6                          165.4                               34.2
# 47                        8817.0                               45.1
# 4                          160.1                               36.1
#
#     Trade in services (% of GDP)  \
# 8                       5.592105
# 49                      5.300000
# 6                       5.592105
# 47                      5.600000
# 4                       5.592105
#
# ...

# %%
some_labels=Brics_labels_tr[:5]

# %%
some_labels
# Out:
# 8     11.3
# 49     5.9
# 6     -1.6
# 47     6.9
# 4      2.3
# Name: GDP Growth, dtype: float64

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([10.43344,  6.56922,  1.495  ,  7.05266,  3.332  ])

# %%
from sklearn.metrics import mean_squared_error
Brics_predictions=model.predict(Brics_num_tr)
lin_mse=mean_squared_error(Brics_predictions, Brics_labels_tr)
lin_rmse=np.sqrt(lin_mse)

# %%
lin_mse
# Out:
# 2.234558407750002

# %%
#from sklearn.model_selection import cross_val_score
#scores=cross_val_score (model, Brics_num_tr, Brics_labels_tr, scoring="neg_mean_squared_error", cv=10 )
#rmse_score=np.sqrt(-scores)

# %%
Brics_te=test_set.drop("GDP Growth", axis=1)
Brics_labels_test= test_set["GDP Growth"].copy()
prepared_data_test=my_pipeline.transform(Brics_te)
Final_predictions=model.predict(prepared_data_test)
Final_mse=mean_squared_error(Final_predictions, Brics_labels_test)
Final_rmse=np.sqrt(lin_mse)
print(Final_predictions, Brics_labels_test)
# Out:
# [ 7.976    9.698    6.989    4.378   10.93032  8.70144 10.317    8.76666
#   4.005    6.953    4.589  ] 43     7.8
# 40    10.6
# 46     6.8
# 12     9.0
# 24    13.0
# 31     8.3
# 17    11.7
# 32     9.1
# 3      7.8
# 30     8.5
# 13    10.8
# Name: GDP Growth, dtype: float64

# %%
Final_predictions
# Out:
# array([ 7.976  ,  9.698  ,  6.989  ,  4.378  , 10.93032,  8.70144,
#        10.317  ,  8.76666,  4.005  ,  6.953  ,  4.589  ])

# %%
Final_rmse
# Out:
# 1.4948439409349734

# %%
from joblib import dump, load
dump(model, 'IIM project.joblib')
# Out:
# ['IIM project.joblib']

# %%
prepared_data[0]
# Out:
# array([-1.1001955 , -1.18796428, -0.65193765, -0.27225041,  0.04661667,
#         0.42890123, -0.02968841,  0.27225041,  0.01098075,  0.53168254,
#        -1.14431508])
